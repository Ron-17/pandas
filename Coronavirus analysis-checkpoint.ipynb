# %%
import pandas as pd
df=pd.read_csv("C:/Users/ghata/Downloads/coronavirus/COVID-19 Coronavirus.csv")
df.head(5)
# Out:
#        Country  Other names ISO 3166-1 alpha-3 CODE  Population Continent  \
# 0  Afghanistan  Afghanistan                     AFG    40462186      Asia
# 1      Albania      Albania                     ALB     2872296    Europe
# 2      Algeria      Algeria                     DZA    45236699    Africa
# 3      Andorra      Andorra                     AND       77481    Europe
# 4       Angola       Angola                     AGO    34654212    Africa
#
#    Total Cases  Total Deaths  Tot Cases//1M pop  Tot Deaths/1M pop  \
# 0       177827          7671               4395                190
# 1       273870          3492              95349               1216
# 2       265691          6874               5873                152
# 3        40024           153             516565               1975
# 4        99194          1900               2862                 55
#
#    Death percentage
# 0          4.313743
# 1          1.275058
# 2          2.587216
# 3          0.382271
# ...

# %%
df.describe()
# Out:
#          Population   Total Cases  Total Deaths  Tot Cases//1M pop  \
# count  2.250000e+02  2.250000e+02  2.250000e+02         225.000000
# mean   3.507321e+07  2.184781e+06  2.744813e+04      136900.373333
# std    1.392418e+08  7.275938e+06  9.689177e+04      145060.340289
# min    8.050000e+02  1.000000e+00  0.000000e+00           9.000000
# 25%    5.665570e+05  2.407100e+04  1.890000e+02       11384.000000
# 50%    5.827911e+06  1.639360e+05  1.965000e+03       88987.000000
# 75%    2.190585e+07  1.092547e+06  1.366000e+04      223335.000000
# max    1.439324e+09  8.183905e+07  1.008222e+06      696044.000000
#
#        Tot Deaths/1M pop  Death percentage
# count         225.000000        225.000000
# mean         1096.715556          1.444125
# std          1195.715543          1.741728
# min             0.000000          0.000000
# 25%           123.000000          0.511291
# 50%           708.000000          1.036905
# 75%          1795.000000          1.977017
# ...

# %%
df.dtypes
# Out:
# Country                     object
# Other names                 object
# ISO 3166-1 alpha-3 CODE     object
# Population                   int64
# Continent                   object
# Total Cases                  int64
# Total Deaths                 int64
# Tot Cases//1M pop            int64
# Tot Deaths/1M pop            int64
# Death percentage           float64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#                Country                Other names ISO 3166-1 alpha-3 CODE  \
# 0          Afghanistan                Afghanistan                     AFG
# 1              Albania                    Albania                     ALB
# 2              Algeria                    Algeria                     DZA
# 3              Andorra                    Andorra                     AND
# 4               Angola                     Angola                     AGO
# ..                 ...                        ...                     ...
# 220  Wallis and Futuna  Wallis and Futuna Islands                     WLF
# 221     Western Sahara             Western Sahara                   ESHÂ
# 222              Yemen                      Yemen                     YEM
# 223             Zambia                     Zambia                     ZMB
# 224           Zimbabwe                   Zimbabwe                     ZWE
#
#      Population Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# ...

# %%
df.dropna(how="all")
# Out:
#                Country                Other names ISO 3166-1 alpha-3 CODE  \
# 0          Afghanistan                Afghanistan                     AFG
# 1              Albania                    Albania                     ALB
# 2              Algeria                    Algeria                     DZA
# 3              Andorra                    Andorra                     AND
# 4               Angola                     Angola                     AGO
# ..                 ...                        ...                     ...
# 220  Wallis and Futuna  Wallis and Futuna Islands                     WLF
# 221     Western Sahara             Western Sahara                   ESHÂ
# 222              Yemen                      Yemen                     YEM
# 223             Zambia                     Zambia                     ZMB
# 224           Zimbabwe                   Zimbabwe                     ZWE
#
#      Population Continent  Total Cases  Total Deaths  Tot Cases//1M pop  \
# ...

# %%
df=df.sort_values("Total Cases",ascending=False)
df
# Out:
#               Country                       Other names  \
# 214               USA          United States of America
# 92              India                             India
# 26             Brazil                            Brazil
# 70             France                            France
# 76            Germany                           Germany
# ..                ...                               ...
# 221    Western Sahara                    Western Sahara
# 148              Niue                              Niue
# 125  Marshall Islands                  Marshall Islands
# 168      Saint Helena                      Saint Helena
# 131        Micronesia  Micronesia (Federated States of)
#
#     ISO 3166-1 alpha-3 CODE  Population                        Continent  \
# 214                     USA   334400597                 Northern America
# 92                      IND  1403754381                             Asia
# ...

# %%
newdf=df.iloc[0:5]
newdf
# Out:
#      Country               Other names ISO 3166-1 alpha-3 CODE  Population  \
# 214      USA  United States of America                     USA   334400597
# 92     India                     India                     IND  1403754381
# 26    Brazil                    Brazil                     BRA   215204501
# 70    France                    France                     FRA    65526369
# 76   Germany                   Germany                     DEU    84252947
#
#                            Continent  Total Cases  Total Deaths  \
# 214                 Northern America     81839052       1008222
# 92                              Asia     43029044        521388
# 26   Latin America and the Caribbean     29999816        660269
# 70                            Europe     25997852        142506
# 76                            Europe     21646375        130563
#
#      Tot Cases//1M pop  Tot Deaths/1M pop  Death percentage
# 214             244734               3015          1.231957
# ...

# %%
df.groupby(["Continent"]).sum().sort_values("Total Cases",ascending=False)
# Out:
#                                  Population  Total Cases  Total Deaths  \
# Continent
# Europe                            748420351    180332483       1775727
# Asia                             4668689344    140957179       1405003
# Northern America                  372846593     85364770       1046062
# Latin America and the Caribbean   661325824     67509231       1686828
# Africa                           1396751613     11764207        252873
# Oceania                            43437948      5647957          9336
#
#                                  Tot Cases//1M pop  Tot Deaths/1M pop  \
# Continent
# Europe                                    14596188             110071
# Asia                                       5015344              30847
# Northern America                           1090035               6611
# Latin America and the Caribbean            6943019              75380
# Africa                                     1782060              17843
# ...

# %%
matrix=df.corr(method='pearson')
matrix
# Out:
#                    Population  Total Cases  Total Deaths  Tot Cases//1M pop  \
# Population           1.000000     0.430687      0.428189          -0.130130
# Total Cases          0.430687     1.000000      0.915263           0.127890
# Total Deaths         0.428189     0.915263      1.000000           0.036561
# Tot Cases//1M pop   -0.130130     0.127890      0.036561           1.000000
# Tot Deaths/1M pop   -0.066485     0.216272      0.289201           0.508630
# Death percentage     0.083387    -0.032520      0.082616          -0.349986
#
#                    Tot Deaths/1M pop  Death percentage
# Population                 -0.066485          0.083387
# Total Cases                 0.216272         -0.032520
# Total Deaths                0.289201          0.082616
# Tot Cases//1M pop           0.508630         -0.349986
# Tot Deaths/1M pop           1.000000          0.061088
# Death percentage            0.061088          1.000000

# %%
corr_pairs = matrix.unstack()

print(corr_pairs)

sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# Population         Population           1.000000
#                    Total Cases          0.430687
#                    Total Deaths         0.428189
#                    Tot Cases//1M pop   -0.130130
#                    Tot Deaths/1M pop   -0.066485
#                    Death percentage     0.083387
# Total Cases        Population           0.430687
#                    Total Cases          1.000000
#                    Total Deaths         0.915263
#                    Tot Cases//1M pop    0.127890
#                    Tot Deaths/1M pop    0.216272
#                    Death percentage    -0.032520
# Total Deaths       Population           0.428189
#                    Total Cases          0.915263
#                    Total Deaths         1.000000
#                    Tot Cases//1M pop    0.036561
#                    Tot Deaths/1M pop    0.289201
#                    Death percentage     0.082616
# Tot Cases//1M pop  Population          -0.130130
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Other names', 'ISO 3166-1 alpha-3 CODE', 'Population',
#        'Continent', 'Total Cases', 'Total Deaths', 'Tot Cases//1M pop',
#        'Tot Deaths/1M pop', 'Death percentage'],
#       dtype='object')

# %%
columns=["Total Cases","Total Deaths"]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for column in columns:
    plt.figure()
    sns.histplot(df[column],bins=[0,0.5,1,1.5,2])

# %%
for column in columns:
    plt.figure()
    sns.kdeplot(df[column])

# %%
df3=df.iloc[0:10]
sns.scatterplot(df3["Country"],df3["Total Cases"])
# Out:
# C:\Users\ghata\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Country', ylabel='Total Cases'>

# %%
import seaborn as sns
sns.heatmap(data=matrix)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(data=matrix)

# %%
import matplotlib.pyplot as plt
plt.plot(df["Total Cases"],df["Total Deaths"])
plt.xlabel("Total Cases")
plt.ylabel("Total Deaths")

plt.show()

# %%
df2=df.iloc[0:4]
plt.bar(df2["Country"],df2["Total Cases"])
plt.show()

# %%
sns.pairplot(data=df)
